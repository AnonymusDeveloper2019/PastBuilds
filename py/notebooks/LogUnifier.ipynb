# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
import re
import hashlib
import numpy as np
pd.set_option('display.max_colwidth', -1)
pd.options.display.max_rows = 200

# %%
projects=['Lang','Math', "Time", "Closure", "Mockito"]

# %%
pd.set_option('display.max_columns', None)  
path='../../analysis/%s/experiment_2/%s_errors.tsv'
project_errors = []
for project in projects:
    errors = pd.read_csv(path%(project,project),sep='\t', encoding='utf-8')
    #del errors['key']
    errors['project'] = project
    project_errors.append(errors)
df = pd.concat(project_errors)
df = df.sort_values(by=['count'], ascending=False)
df = df.reset_index()
df = df[['project', 'trace','count','type']]
#df = df.query('count >= 100')
#df = df[df.type=="DEVELOPER_ERROR"]
df = df.reset_index()
df[['project', 'trace','count','type']]
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   if __name__ == '__main__':
#      project  \
# 0    Lang
# 1    Math
# 2    Math
# 3    Lang
# 4    Lang
# 5    Math
# 6    Time
# 7    Math
# 8    Math
# 9    Math
# 10   Math
# 11   Math
# 12   Mockito
# 13   Mockito
# 14   Math
# 15   Mockito
# 16   Mockito
# 17   Math
# 18   Mockito
# 19   Math
# 20   Mockito
# 21   Mockito
# 22   Lang
# 23   Mockito
# 24   Lang
# 25   Mockito
# 26   Math
# 27   Math
# 28   Math
# 29   Time
# 30   Lang
# 31   Mockito
# 32   Time
# 33   Time
# 34   Math
# 35   Mockito
# 36   Mockito
# 37   Time
# 38   Time
# 39   Mockito
# 40   Mockito
# 41   Mockito
# 42   Mockito
# 43   Time
# 44   Mockito
# 45   Mockito
# ...
