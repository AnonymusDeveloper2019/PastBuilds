# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
import re
import hashlib
import numpy as np

# %%
data = pd.read_csv("report_step_1.csv")
data.head()
# Out:
#    id   commit    build  exec_time  \
# 0   0  0da657a  SUCCESS       40.0
# 1   1  1780da7  SUCCESS       18.0
# 2   2  3815732  SUCCESS       18.0
# 3   3  8dc518b  SUCCESS       18.0
# 4   4  8a71be7  SUCCESS       17.0
#
#                                              comment fix
# 0  [MATH-996] Fix creation of Fraction/BigFractio...  {}
# 1           Added Thorsten Schaefer to contributors.  {}
# 2                                Fix change message.  {}
# 3  [MATH-1028] Added new distance metric EarthMov...  {}
# 4                                       Fix Id tags.  {}

# %% [markdown]
# ## Calculamos el número de builds de cada tipo

# %%
data[(data['build'] == 'SUCCESS')].count()
# Out:
# id           3858
# commit       3858
# build        3858
# exec_time    3858
# comment      3858
# fix          3858
# dtype: int64

# %%
data[(data['build'] == 'FAIL')].count()
# Out:
# id           1020
# commit       1020
# build        1020
# exec_time    1020
# comment      1020
# fix          1020
# dtype: int64

# %%
def plot_histogram(total_commits, jump, limit, title):
    fails_list=[]
    success_list=[]
    for index, row in data.iterrows():
        if row['build'] == "SUCCESS":
            success_list.append(row['id'])
        else:
            fails_list.append(row['id'])

    bins = np.arange(0,total_commits,jump)

    fig, ax = plt.subplots(figsize=(14, 4))
    _, bins, patches = plt.hist([np.clip(success_list, bins[0], bins[-1]),
                                 np.clip(fails_list, bins[0], bins[-1])],
                                normed=1,  # normed is deprecated; replace with density
                                stacked=True,
                                #density=True,
                                bins=bins, color=['#4b8869', '#a82e2e'], label=['SUCCESS', 'FAIL'])
    
    xlabels = bins[1:].astype(str)
    xlabels[-1] += '+'

    N_labels = len(xlabels)
    
    plt.xticks(jump * np.arange(N_labels) + jump/2)
    ax.set_xticklabels(xlabels)

    plt.yticks([])
    plt.title(title, fontsize=20)
    plt.setp(patches, linewidth=0)
    plt.legend(loc='upper left', prop={'size': 16})

    fig.tight_layout()
    plt.xlim([0, limit])
    plt.tick_params(axis='both', labelsize=14)
    
    plt.savefig('success_fail_hist.png')
    plt.show()
plot_histogram(5000,200,4600, "Commit status history in Math project")

# %% [markdown]
# ## Recogemos todos los fails y los separamos en grupos

# %%
import csv

with open("report_step_1.csv") as csvfile:
    reader = csv.DictReader(csvfile)
    csvDict = dict()
    for row in reader:
        csvDict[row['commit']] = row

# %%
groups_of_fails = []
fails = []
current_group = []
for k,v in csvDict.items():
    if v['build'] == "SUCCESS" and len(current_group)>0:
        groups_of_fails.append(current_group)
        current_group = []
    if v['build'] == "FAIL":
        current_group.append(v)
        fails.append(v)
if len(current_group)>0:
    groups_of_fails.append(current_group)

# %%
moreThan100 = []
for g in groups_of_fails:
    if len(g) > 100:
        moreThan100.append(g)

# %%
len(groups_of_fails)
# Out:
# 29

# %% [markdown]
# ## Obtenemos los logs de cada commit con build fail

# %%
for fail in fails:
    with open("logs/%s-%s.log"%(fail['id'], fail['commit'])) as f: 
        r_data = f.read()
        fail['log'] = r_data

# %% [markdown]
# ## Agrupamos los commits por sus logs

# %%
def cleanLog(text):
    return text.replace('\n', ' ').replace('\t', ' ')

# %%
errors=dict()
def addError(error_type, error_text, commit):
    hash_object = hashlib.md5(error_text.encode())
    hash_key = hash_object.hexdigest()
    if hash_key in errors:
        errors[hash_key]['count'] +=1
        errors[hash_key]['commits'].append(commit)
    else:
        errors[hash_key] = {
            'key': hash_key,
            'type': error_type,
            'message': cleanLog(error_text),
            'commits': [commit],
            'count': 1
        }

# %%
for fail in fails:
    
    detected = False
    
    for java_error in re.finditer('can\'t read pom.xml: No such file or directory', fail['log']):
        addError("NO_POM_ERROR", java_error.group(0), fail['commit'])
        detected = True
        break
    if detected: continue
        
    for goal_error in re.finditer('Failed to execute goal org.apache.maven.plugins:maven-compiler-plugin', fail['log']):
        addError("GOAL_ERROR", goal_error.group(0), fail['commit'])
        detected = True
        break
    if detected: continue
        
    for goal_error in re.finditer('Failed to execute goal .*', fail['log']):
        addError("GOAL_ERROR", goal_error.group(0), fail['commit'])
        detected = True
        break
    if detected: continue
        
    if not detected:
        addError("UNKNOWN_ERROR", fail['log'], fail['commit'])

# %%
df = pd.DataFrame.from_dict(errors, orient='index')
df.groupby(['type']).agg({'count': 'sum'})
# Out:
#               count
# type
# GOAL_ERROR      154
# NO_POM_ERROR    866

# %%
df.groupby(['key', 'type', 'message']).agg({'count': 'sum'}).sort_values(by=['count'], ascending=False)
# Out:
#                                                                                                   count
# key                              type         message
# 8b2b44943a6d491ed4a37fdae7d112d4 NO_POM_ERROR can't read pom.xml: No such file or directory         866
# 515863b0649a6f58ee42e47fdebbff00 GOAL_ERROR   Failed to execute goal org.apache.maven.plugins...     57
# bbbe96be1a3170c4650e5d43b245657f GOAL_ERROR   Failed to execute goal org.jacoco:jacoco-maven-...     52
# 9c7b3c7ef3a0f7d854015b629e8fe10e GOAL_ERROR   Failed to execute goal org.codehaus.mojo:cobert...     43
# 6ca3cfacdaaa25d4df9ecb4ac99b9551 GOAL_ERROR   Failed to execute goal org.codehaus.mojo:clirr-...      1
# 8ce618dc3d74516c3c42c8f1c1603f79 GOAL_ERROR   Failed to execute goal org.codehaus.mojo:cobert...      1

# %%
error_id = "8b2b44943a6d491ed4a37fdae7d112d4"
errors[error_id]['commits'][0]
# Out:
# '8ac52f7'

# %%
# commit_id="8ac52f7"
# csvDict[commit_id]

# %%
# success_commits = []
# for k,v in csvDict.items():
#     if v['build'] == "SUCCESS" and len(current_group)>0:
#         success_commits.append(v['commit'])
#         print(v['commit'])
# with open('success_commits.txt', 'w') as f:
#     for commit in success_commits:
#         f.write("%s\n" % commit)
# Out:
# 0da657a
# 1780da7
# 3815732
# 8dc518b
# 8a71be7
# ae36380
# 7eed992
# 0039af5
# 66b1ab0
# 4867e1f
# 784b124
# 48b1e6a
# 1111de7
# d056884
# a4e559e
# dba03ef
# d40d9b4
# e7d45d8
# 577613d
# fd5221c
# 270a569
# b6cdd7f
# f1e085f
# 2f24562
# 2650440
# 699de4b
# f327482
# a3dfabc
# 4460156
# 2a89064
# ac5b0fc
# 54540b3
# 5e2b0fb
# 734d92b
# 3cef1d6
# 2983371
# 21baa96
# 92c4697
# de42095
# d372fd0
# 4a203dc
# f92c335
# 1cef886
# 2ca4468
# e80ef47
# a86288b
# 5221d07
# 12e7749
# 15339c0
# 0ca7d02
# 1c8b410
# 30f61ed
# 81aa19e
# 8d91da2
# b2d0c9b
# f0c3826
# 8613b13
# 73181ab
# 8ed4731
# 1324363
# 633c613
# 0a7aaae
# 7649266
# 80384c4
# a50ec42
# dd7d68a
# 1f84813
# a818970
# 9504290
# 1676524
# 3eea557
# 803669e
# 2fd2fdf
# 55b69a5
# 18e0885
# e74f252
# 0c82ade
# 277e617
# d609e65
# 6921a39
# 3348d51
# a67fb14
# f2de79d
# 76c6f56
# 7f930ae
# 8e68755
# 6bffa0e
# 79f57d7
# 9d25167
# fad32c1
# 2732c85
# 9dc18c6
# 5ee79e5
# ae0435a
# 79c3286
# a032121
# 69984ff
# c6c8aea
# 3bdf9f7
# 8536c9b
# bedb466
# c0a9558
# ecf79d0
# 56d20c1
# 85ff922
# 673fa25
# 174d7e6
# 52b73a9
# e4304fa
# 733ec7c
# 7b59404
# a1d24df
# c228c1f
# d85d76d
# c8beebc
# 5e23755
# fc10c53
# c7f3ba9
# a3294d8
# 365a42b
# 03c36c9
# 33cf091
# 0c57fad
# 032b2c6
# 2f9df81
# 1b9a586
# be4b9ef
# 90fb652
# 4b8cf0c
# 3c23e7a
# 99aef4e
# b35d0a2
# 6d37cca
# b7977ff
# 31c8c45
# 1e04a48
# 1ab8950
# ca85bc1
# 7803e34
# 02c690b
# a5d0977
# 53e990d
# d23332f
# c540f8f
# 1d7485a
# d1cb752
# f8ef91f
# b315c9b
# 87f4979
# 813ef69
# f727f77
# 87d1c82
# 8289cdc
# 7308a30
# 91c2be6
# d727f31
# e00851f
# a429952
# 6aa0dc4
# c96fc57
# 0d2010f
# 50cfc00
# 0bcd8de
# d234ca6
# 9e8309b
# 8a6f965
# 685eaa8
# 7e2d8b8
# b9ccbb7
# d1c1405
# 0af30cf
# 0c442a2
# 4109263
# 70ab293
# 1306141
# 808691b
# 3130c9a
# 6ba5a58
# 4f04cb2
# 2225f34
# cfc714c
# e54a1c9
# f5bcba8
# 4a765d1
# 8673fb1
# 8451c58
# f5e42b4
# 437df27
# 00298bf
# bf7b5c1
# 297e9fd
# ce371c9
# 8b0fb3d
# 6d7fe5d
# bd45bbd
# 1793c8d
# 1957877
# 7de10c8
# 196a438
# 419a052
# 6c9d06a
# 1cd68ee
# 96cd02e
# 792a0be
# f227366
# a90e689
# d037aa5
# b164140
# 2cbe8ff
# acb3a83
# 3f96c7a
# 22362f4
# 12dfb9f
# ca5886b
# 565d8d1
# 13e1e37
# 1e1b887
# 94cf734
# eaf773a
# d6efeb5
# 6ea2bf4
# a6e271c
# 889ff1c
# c11dee3
# 5793cad
# 493b865
# 5e42709
# 7a5cb6e
# 9a59bc1
# 9aeffe4
# ce22e65
# c5806b0
# c5a4a4f
# 56ba368
# 2dda4cf
# 1fd0f7a
# f895506
# 4ca845c
# d361da0
# 196e631
# 5504647
# 3078642
# a58df6c
# b0fc8e3
# 97cf5aa
# c72bf2d
# 1d4f3a0
# 04d9684
# 26c817f
# 3b21457
# 2b7e469
# 052b3d5
# 1395aed
# bfb0859
# d5a5da0
# 7d8f54c
# 3b7efc5
# 4e0630e
# 80e065b
# c61875d
# de98c0f
# c929aee
# c6b4666
# 85de48c
# 5703963
# c0279a5
# dc9eb31
# 5876d84
# 171d317
# 79e3caa
# 6e60dc7
# a71b633
# dcc13b2
# 5e90090
# 9b5247c
# 16361b8
# 89b3b73
# d2617b2
# 79abf3c
# 7e2ffcc
# d2a916e
# 9c5bbab
# ad20e42
# eedff09
# be040b5
# 1d822a8
# 34f2ea5
# 007b4c1
# a019a12
# e81a106
# 71d2608
# 44bd80f
# 06b393d
# e972c03
# 19c85a1
# aa2bd1d
# 02f64e7
# 7418895
# 0248f07
# 953bab3
# 34391a1
# 9e0eaa7
# 35a4d24
# 66238fa
# b4b221d
# 58da2ec
# 4150102
# b393094
# d9aef65
# cc82d38
# 67fc870
# a273090
# 80cdfa2
# 6f84c8f
# 71a785d
# c2fbe47
# 624f670
# 8079ea5
# a6b2e99
# 0f37f87
# 80180b2
# 3d2561d
# ff2cfb2
# a3f07ff
# 21e1870
# 67ddcbf
# acd679c
# 249c878
# cc19d1b
# c378903
# 3d57e11
# 9aca058
# 96f4ce7
# ef9aee5
# db3ed53
# 9d5668f
# 739785d
# d3e0209
# 1200bf1
# 9f3a7dc
# 725c5f2
# b4d5271
# c2d9dc9
# c73c80b
# 45396be
# c8df0b8
# 8d361a3
# ed03c1e
# ae644af
# abe9cb8
# 3418805
# 9b6e512
# 715bce6
# c942b0f
# dbefec8
# 16899c1
# 5cc5ae1
# 2b4dc4d
# b003aab
# 95ffd4c
# d10ba4d
# 3954b85
# e23eb4d
# e4d49aa
# b0799d9
# 75e6ddd
# b68a5be
# 4f5a775
# f2796cf
# 31732f6
# 003bfee
# 84eadc8
# 107b3d9
# 7438d67
# 6ec823b
# a3a1f9a
# 67017f3
# e1ac02b
# cab3350
# 0eaefad
# ce3f5c4
# a53f989
# 64763c3
# f79046f
# 5e31110
# 0cfae8b
# 3b79050
# fae5d64
# b734013
# ccd1378
# 7f9204f
# 57a21d8
# e8a6688
# 2bfd2cc
# 144a521
# 3a34a00
# 638563a
# bebe022
# c9aa539
# d501e58
# 4bc3f63
# ecb2a66
# 5447416
# 71d1c3a
# 5e60c4b
# 386325d
# 854a7a1
# fb15176
# 5f7a481
# b221a73
# efcf91b
# 6691271
# a68723d
# 46d4d64
# 875ed1f
# 87324e5
# 15f15ea
# b57377e
# 44e0590
# 332bd8d
# 92576cc
# c7b14e5
# 3330dd2
# 709dbab
# a0bb64a
# e544fe1
# 1e33436
# 9b86e63
# d8a334f
# 4ceada1
# 087eea9
# 46e72f8
# c5e1819
# 689422d
# f536497
# ad8f51e
# 211cb1d
# 1f160db
# 3b4b848
# a2839fc
# b29635c
# b104209
# 2074ef1
# e0552ea
# 4a91d03
# a9a26ba
# 2abb760
# be48cdb
# 1a8c5fd
# 2f90cfd
# c78f0c0
# e9c43d6
# 2981b35
# 8c773e3
# 4969e39
# 7852db4
# c1b0503
# 2e0e68c
# f9a3b1b
# dc2e486
# fe2843d
# 136233e
# a752a37
# 2778d8f
# e61c8c5
# 72f8709
# 16117a4
# 11aca63
# 12dd10f
# ab02fd9
# af2a85b
# 0dd3e5e
# 5500bb8
# 6c8a902
# 148ec7b
# 3f69405
# 314a973
# eb9cdbe
# ca6d8b8
# 527922a
# f5af07f
# f3a4e0b
# 639fd3d
# cd7b7ac
# 947dbf7
# 4d73889
# a0de116
# 2589445
# 0d0f90a
# 44f670d
# 61b6d87
# 7ac9b65
# 8130aab
# 4e0f9b7
# d141e8c
# 4a2c4c6
# 4fb8cf9
# 49bfc66
# b804542
# d370aea
# f377db3
# 2885ba1
# 039842e
# a00f224
# 0d9020c
# 52d616f
# cdd8d43
# 29adbd0
# fd1ccac
# 2110ba0
# 2a7be0b
# 1e40649
# 734ffc6
# 1d0f8c0
# ece8fb2
# 7364e7a
# d4c5054
# 717e750
# 1f0d62c
# 0a4491e
# 988334f
# d377887
# 7a5b74b
# 3eaff6c
# 7230691
# 80035b2
# 3771d22
# e599e92
# 893f858
# 4bf4af8
# d8a107f
# ec145be
# ce6d20c
# ba204bf
# 4fda2ec
# 289e7fa
# f0e5890
# b3cbce4
# c657a84
# 621806b
# 0761116
# 3a610d3
# 05366a5
# 146638a
# 84a7829
# c88186e
# 0320f5e
# 1e4d8a5
# 9893a19
# b4d3b71
# d0d685f
# 9a4116d
# b2f7873
# 952caec
# 9adba00
# 3d76b1e
# 4585a30
# ab871bc
# 2be110d
# 2682318
# 30bb9db
# e0f6015
# 94ae35f
# d84669a
# 3ce97db
# f8e1f63
# b83009e
# 0b9e1f5
# 7cee231
# 71e7324
# f056320
# e84fc8a
# 46fda84
# ec7c825
# 896f15a
# 72cd0ef
# be8e813
# a55c142
# 5f1b2df
# 7c7d7e8
# 6e62aef
# 4c5534f
# 25aad2a
# 9afe132
# 7b45e6f
# f3599ae
# 7c78cae
# 0b5c213
# f78bd2b
# 853a793
# 300d34b
# b4d82b8
# b66f972
# b0d18a4
# e457a7c
# 138e161
# 7f7c485
# 0dd4598
# abb204e
# 4e38287
# c73fad0
# efa9de0
# 5a50073
# dea09c7
# d5a9dab
# 479ef5d
# 8ae7ff2
# 4a8363f
# 9e9a52e
# 72b3ebd
# 3f6052c
# 157355e
# e20f900
# 14c51c3
# ff01266
# 27df4f9
# e884a3b
# 904c30a
# b02fa4a
# f1d0745
# 767ba4d
# 7fbec65
# 42ae2c2
# 39d423c
# 2c00c4a
# f36f4f4
# 74ca9ec
# 9eab03d
# ffd8452
# a76049d
# 461ccf3
# 2a535e7
# be6ac45
# 4e89d4e
# 265a697
# f015c76
# 3f753c8
# a62ba88
# c457f57
# 7f836b5
# 0b5b0f6
# ede9b56
# 468ed85
# dbb408e
# adb0bc7
# 410bf24
# 062250d
# 7366eb6
# 066aae5
# 7f978ae
# b586cfa
# ca031b9
# f2288dd
# b34c6fd
# b9c9a47
# 78bc8d3
# e1925c9
# 6f31135
# 8176f04
# 1755c3c
# 9fb6d63
# 85b6aa6
# 2d17971
# ba38039
# 3a6d84a
# c48b86e
# c1de4ed
# c422db8
# e4ed959
# 472da04
# dc51e1e
# b56fe17
# b0cba9a
# 51461f1
# 40007fe
# dc68883
# f1b04e9
# 2b4c1f8
# 862652d
# 90d3cc4
# a12ed0e
# 2569f06
# 0aa7e7a
# 4fdc478
# 484138d
# b6b3238
# 4662531
# d5ff460
# 4e21bb6
# 6b589ca
# 1f7c89c
# 79d55e7
# fab7d8e
# 9a128a1
# 22ceb31
# 5f2b748
# 7e4483e
# 67502e7
# 2e4cf96
# eb81516
# a5822a6
# 7be3196
# d74b5e2
# 439009f
# 0c6eb89
# 6cb05c1
# 8f8b6e0
# 21af910
# e1ba170
# 039828a
# fc502e0
# c2d90f7
# ede5a28
# 8756566
# ce9df69
# 35a0a78
# e3d956a
# 5b46fd0
# ef55f44
# c0e9a78
# 35ad54c
# 4a5f720
# a1d1658
# 54d5fb5
# 43d4d42
# 97c7fae
# e779892
# 0a8dd1c
# 1ebdd87
# 978b3d6
# 4de0d1a
# be09075
# 036ba94
# 0ba6101
# 61e00d3
# 4026c69
# f5ebd6c
# a79cdc8
# 996dd99
# 3320159
# 5c72ac0
# 45d0ed8
# b7e82a7
# 6c3ba12
# b4dc65b
# 1bb1ae3
# 5b071e6
# 33df774
# 1c92a2e
# 093b098
# c09d588
# 4f0f595
# 9ddd494
# 2cb82cc
# 797519f
# 6adc7f6
# 67dffec
# dbbf5b2
# a1a421f
# a87ba1f
# 85de10a
# 62f6e15
# 60a5394
# 8a668a8
# e3ee738
# b68b4d6
# 9330689
# 7633a84
# f3d763a
# 473d151
# f807797
# 96dfe1a
# 019a042
# 23beda6
# 0a2da59
# 53f5335
# 5466665
# d33efe9
# 513047e
# 58ddcf7
# f8b6d31
# 86728b7
# 8bb009e
# 9b01f8c
# 1250546
# c50ec33
# 5d7868b
# 54b062e
# 695d75f
# cd7d5ab
# 9d552d4
# dd59eb4
# 03ad335
# 480a0aa
# f1791c6
# 442283c
# b768aa1
# 5fa6a20
# 8f2603b
# b6f2d03
# 7770346
# 5075b8f
# c8cd8da
# 1566dd3
# 5f2077b
# d3fc5af
# a55c951
# 16bcfbd
# 043e1d6
# 22ee0f1
# fd27590
# e434abd
# f5582b7
# 2e92344
# 263e2f4
# a24ddac
# 661f46b
# f54a697
# 2a346e5
# 117245d
# b47a3e5
# 567f081
# 94c8949
# eb0e423
# ae54fc7
# 258de9d
# 0b0f111
# e5d4dac
# 9733973
# 5b9f134
# 88ecdbe
# 72f9dc8
# bd88f84
# 54add48
# 87936d2
# 9f38d7c
# 0781828
# 619a96d
# 085bc9f
# 55049ef
# d4b1998
# c93d8d4
# 764e70c
# c04c01c
# 04ced3c
# 5462eca
# 463e936
# 3baf9e9
# c65ed0c
# 5519ebe
# 189e0b1
# 6244cef
# c67a524
# ff0c841
# 2b1a5f4
# f3eda45
# 802a2a0
# a3593b1
# aacf5b4
# c2892d8
# 6bb8d78
# ebc1099
# 74b5d93
# e5dd34b
# 490ec33
# 717b56b
# adcb11a
# 8c0f61d
# f1a0493
# db0926e
# b22e2b5
# 7cac17f
# dc3a794
# f8c8f36
# 9d79561
# e383eb0
# 3771443
# 9d5dd23
# 5d06a22
# 7a70bf6
# baad7bd
# d2110ad
# 3385d1f
# 234d22f
# 58438af
# 0b0d546
# 1a7b596
# 74d2d6b
# 447f609
# 3e968bd
# 9ba65a4
# 6352c3d
# 8a84349
# 07b8843
# e4b7006
# af94313
# 634e672
# eb50c98
# 48a95a9
# 0221dcc
# 5b79578
# c1494f2
# a5f1691
# 062332f
# d36722a
# d793410
# 92fcf5e
# 8013e76
# 77fc6fc
# 29d5df5
# bb5612d
# 798d214
# a428cfc
# cf4855e
# d4d928c
# f53a01e
# 7bbddc2
# 350b2b1
# f25cf01
# 64cca1d
# 076a3c0
# 39f47ff
# 83af9ce
# 2ea21e3
# a25e7f7
# 631c5bc
# 5956742
# 2464bb2
# 9d82a03
# 9e97426
# a300453
# f1703ce
# 895dc5f
# 50c280a
# 4451a1d
# 53dc23b
# be4cf2b
# 46ffc57
# dcbfce4
# a2e7bb6
# aff0231
# 609ab4f
# 57afb23
# 9632f16
# d295a1b
# 3937d92
# 7f55447
# 3fd0dea
# 7389385
# f311925
# 94239f2
# 5d236a3
# 7a58901
# 2cdae2e
# b9ee639
# 97739c8
# a7a8be5
# 09b43a8
# 0205f25
# 108d897
# 8eb9048
# 6a75999
# 6a45aa9
# b5d4a9b
# 6f8bcd4
# e5f3c5a
# c5c363c
# 6087265
# 52ba41f
# 1a73125
# 30d168e
# 05ac740
# 2c60f01
# e7e7a42
# 52525f0
# 6d672bf
# 1a43530
# f1d5430
# 41748ce
# 0eb7fa4
# 69174a4
# a6340b6
# 67ad156
# 763866c
# 45cad58
# 4a30cbb
# 09d7a6a
# 1c9a51a
# df55d39
# 125b95c
# 2d846db
# 6a5ef01
# 6684eb1
# cc3c43e
# 8f1afdf
# e60890d
# f81847d
# 8d64783
# 454235d
# 2c4839d
# d739532
# a09394c
# a916046
# 2d75045
# 13da14c
# 04b07ea
# 5aa7ce7
# 522596a
# 4efa799
# 1347c82
# c14e02b
# 2a55ee2
# 64ee565
# b52eeaf
# 0749a48
# e6ec59b
# 8314db7
# e3a2f14
# 3ef7931
# e5c7e40
# 2bc9091
# 53a6c84
# 609c25f
# 6b67f82
# cdb2314
# 85ade8e
# dad8515
# f3135ff
# f498331
# 36d811b
# b583987
# 665a0f0
# c64d093
# 21b4e6c
# d04a778
# 4bf1d34
# aa0ccf3
# 771776a
# 216ac00
# 54e26e0
# b4744b0
# 0c00c93
# c9bf3c0
# 02e0ba1
# c6466e7
# e786b2c
# 3ce388e
# 520f36b
# b91b3ef
# 11a7fd2
# c72e5a8
# 1f096bb
# 0ed28b0
# b8bc9b8
# a5d8d11
# 88f944e
# e23e91a
# 0a0a4f7
# 478aeb5
# 1d555f0
# 088aa7d
# 6a1db61
# faf72c3
# 1ae549e
# ffe7f93
# 6f13860
# 9b66141
# 9c9ac39
# 3bed83a
# 50909f9
# c6225ad
# 641ff18
# 13ab872
# 8dae192
# ac3759a
# 2bd1b8d
# 60f8b1a
# 4ae8acf
# e8b2a42
# e914fd7
# 4e96a73
# 7d7f483
# d0bed88
# e616c56
# 8ee0fbf
# e2b200d
# 7427a2b
# 4d2710a
# 7730b42
# beadf37
# 52ac204
# d79dc3f
# 10a2f49
# 855943f
# 810ac94
# 7af9a3f
# 3ad9a6d
# 71042f0
# 4f2a438
# d112c9a
# 78f6896
# e6f32e0
# 4d1edd0
# c28a68b
# de61d0d
# 6105131
# fd75324
# cf82257
# ad0adeb
# 9751c64
# d05a936
# 233c248
# b136e9c
# ba34e0d
# a67ffcb
# 352c7d8
# e045f83
# f0f8d4c
# fda898d
# 4fc5b43
# b3d1eda
# f701074
# be69134
# e2f56ea
# fd060f7
# 8ac20d8
# de472c3
# b3fdbcf
# 55b85e7
# 6182d4c
# ae81b9d
# 3edc252
# 2d40264
# ad1bad0
# 591a2e8
# 627520b
# 534ccb9
# 64c338d
# 8df703c
# 2d8411d
# d2e4a07
# 4af3b3b
# da7c8ca
# 856fa01
# 3eb4dcd
# 539d125
# 5dc9957
# 34d1a7b
# e031177
# 0c12cb8
# 85a9a7b
# 29354f5
# ad8a28c
# 3e69b32
# 92921a4
# bca3519
# a37a9ae
# 95199ce
# 95bdd67
# cbcf4d2
# eb771a0
# 48151d5
# 34c041f
# 90e65fd
# b13d9e1
# 53a80e5
# 96673d8
# 4a6df44
# 0524672
# 1450a1c
# bd56278
# e1eb19d
# 7e2a009
# 56c9e48
# 695d2dc
# 0391a5f
# f5eaefb
# f6effc0
# 28e84c5
# e10108e
# f2b7462
# 8409d9a
# 31451a7
# 6b1d586
# 2d698e4
# 5325732
# 1a15d5f
# 966d2ee
# d50a175
# ced14c6
# ebf0cfc
# b8733ba
# de87563
# ac345ad
# 44b558e
# d6ddfb5
# ad57102
# 21cb65e
# e038f28
# 02da498
# cc9b896
# 4fb7f83
# 25ac724
# 768f5be
# 5a8be77
# 07480af
# 8b72006
# fc871d7
# 5e4c514
# d051a58
# 2a04f60
# 5f764ae
# b9219d7
# 6c2bc82
# b09f60a
# 6961b42
# 222c765
# 07cc864
# c8f524f
# 2fa03a2
# 7877daf
# 5062a57
# e67840f
# df99e89
# 8cbfe1b
# 2e2a0ac
# e67d4e7
# 263601a
# dada2f9
# 84394a9
# d8f5555
# 89040e4
# 00fcbbb
# fafc61e
# 4918ffc
# 7273ca1
# c512753
# 9744c65
# d1c0554
# 7695f21
# 2cb250c
# 67c4dfd
# bf5de5b
# ee3b20c
# e898522
# e45ec57
# 3bc3c15
# 29f55a6
# 882a2ff
# c2da421
# 5680510
# 40ee298
# 05a5b00
# d34f4af
# bc097a7
# 6dde208
# 0d7d026
# 65ed08e
# de147e5
# 0482f58
# 947d342
# 09fd185
# b22056a
# 798554a
# dc78278
# 1935989
# 415fdc3
# 4552822
# 14ab442
# 8dde2c3
# 59bd46b
# 32bd7b2
# 0b144c2
# 641d435
# d4df0e5
# c5420b3
# 4e026a1
# b5c5368
# bb06e31
# 2fab8c5
# d7238ca
# b4af1ec
# f84d2e0
# af70c52
# 705c8bf
# c9e3f7f
# 37d45af
# f5d72c5
# b1fe105
# 54b1ea1
# d155196
# 71df522
# cebe050
# ba827ef
# 7f5762d
# 89153e7
# b255e2c
# 188ef9c
# 2cec1ff
# 999b7d3
# 8e3e57b
# 0054e33
# 711d6b9
# f6fddf9
# 55259fe
# 3dedb20
# 3dcd107
# cda4524
# 66f8169
# 99fe5ba
# 72d2416
# 17c6d82
# 6ae7300
# 2701ed7
# 71bc39e
# 91cc42b
# 74e0029
# c23859f
# 6c96efc
# 790c956
# b423ba6
# f8160b4
# 917690c
# 01f68f2
# d783dd0
# 47404f6
# bb4bd74
# b39e2d0
# 660821d
# 3d67eb0
# 153505b
# 843f20d
# 5ef7821
# ab5aadd
# 18823c8
# 4c27ae2
# 814d15a
# 985c3c5
# b653959
# 6a4d871
# bab8c17
# 68d2ef8
# 3779908
# af3fffb
# 1ae0a97
# b7c6f9c
# c8becc7
# efa7825
# e7bbbbc
# ecf5f29
# 3f3f515
# 783ab0a
# 27328db
# fc3adf6
# 36f18cd
# ebb6228
# d8153cb
# 7f33400
# 00933c7
# 8a69aab
# b43e6a0
# 7298d40
# 4843259
# f510a29
# a0c14c5
# 882556e
# 91e6ac5
# bfd118d
# 134a2b8
# cef8d30
# e98a500
# 800943e
# e579c21
# ba6f308
# f3f6438
# beb4b5e
# 6126238
# e98ce06
# dcffd63
# f859fcc
# 7841eee
# dd8da34
# 7b9c8b7
# dcae84b
# c282a04
# e277619
# 10dac9a
# 4b022bf
# 2822d5e
# a1beb6a
# 9a7cdf6
# b4ad520
# fa457c0
# be5f9de
# 740e834
# 013fe63
# 962e780
# e564e38
# bdf6eb6
# f1cf90c
# f2b4d16
# 2052f37
# b3cbb09
# c6b4fef
# d3bb6ed
# 4d81fcc
# 7ff8ef3
# 7fe539d
# 2164e7e
# dae607e
# b936a46
# 384ccda
# 8be749d
# 3f9e7a9
# c263976
# a4a9dbb
# 942f37b
# 67c628a
# 273ca6b
# 4e340f7
# 8c2d5d1
# 73d32c1
# f6d4c8c
# 88c4506
# 061a4de
# 0454f76
# ed8164e
# 73a1cbc
# 851104e
# 7a37b00
# e70944b
# b56063b
# 393b131
# 3e3fec5
# 0a29c86
# 8082164
# 5b07ef0
# 681ce01
# 3b68757
# d834155
# dfd063c
# 7c08bb8
# 9da1a6b
# 434ed97
# 296f11e
# 51ad790
# 1e75292
# ae3292a
# 182c84f
# 15dec72
# d12cdaf
# fbd5b01
# 765a556
# d7dc40e
# 47bb4fa
# 8a211d3
# 7622878
# 04bcaf9
# 8c7e77b
# 9256cd2
# 2143ffd
# c577464
# b2f348f
# 5e4424a
# 5191b82
# 4f655f0
# 29f1fea
# 722d5d9
# cf64a0a
# d11bdd2
# 1bf4ee0
# 249404b
# 7e2ded1
# 2174768
# 5f6067b
# 644e4d4
# bbde275
# d94a128
# 20287ec
# b61ea94
# 53c8cec
# 4d99470
# f9f0e18
# ceb551b
# bf1e414
# 3f4c6ba
# bad616b
# 4d822c7
# cbc94ef
# 8dcd1af
# faa0a1d
# a95382c
# c0a9493
# c483d25
# 57e9718
# 7f56c46
# 62eb522
# 857230b
# 9d6a1f3
# b88b041
# 8546acb
# 9eb32b0
# be8c8ed
# 6be2cd4
# 186e983
# 4113d09
# a727ba2
# dc7c902
# 5e379d2
# 87e0de0
# 994756b
# 17d8067
# cec984b
# cad6e4a
# 3ff5ce6
# dd4efa4
# b59e974
# e24e9c1
# bc4e9db
# 4a702db
# eb16d73
# b3ac96e
# 4144ca9
# e310cc1
# ff5e6b7
# b9d91ae
# b0adfd0
# 7e8fbc3
# f65b2c7
# 60d96e0
# 2225164
# 3f45e70
# 053a0ab
# d6c8172
# e730c83
# 3d931a3
# f573c31
# a66879e
# 3121f8d
# ab1d18c
# c24c565
# 31017e0
# 5934ec9
# d87651f
# 9bbb160
# 47c98b3
# b370aff
# a4b2642
# 0b5f157
# 9398cf6
# cb11fdc
# 3f0b2ae
# 1bdc0e9
# ce90e21
# 2119976
# c5262ff
# a00cb54
# de98bd2
# 1d5be06
# 04e8bd5
# 4a13c4c
# 9daae47
# 72c673a
# 561c792
# 128669f
# 64f6c0c
# cb83d72
# 44a4ca8
# a318e0e
# 01f9d48
# 4f76c15
# 83ba985
# 4fc19e3
# b3c9889
# 07c6c98
# f5676eb
# a423996
# 5bb6b6d
# d53b9e9
# 4e6d8b6
# 93aea79
# bb6100b
# da85505
# 9e6b0f8
# 5f10148
# 9776e6e
# e129944
# 7aa9eea
# f64c9ae
# 4aa93e5
# 4ca1ded
# 2801903
# 91eee49
# e87ed62
# db09937
# 742c710
# 7841d2b
# d2c3198
# 05e4d4b
# a94bd56
# 6695c90
# 2500eb7
# d5d62a5
# fee41d9
# 63cf988
# 87c292b
# 45c0929
# 8204789
# 1186b56
# 2a4cac1
# 59ed630
# 9639c6a
# ed77246
# 6809f1b
# 287f41b
# 4512625
# b23cb35
# 2fa4443
# a004b8b
# bab9c78
# b71dafd
# ddc3ce7
# 06ce74b
# 5511456
# 5a27ee8
# fd4808e
# f76a8f9
# 1063edd
# 7b67dd4
# 2b3dc10
# 4ef0383
# e247b95
# a8530be
# 44840e0
# 235e22f
# 1f0b0b2
# 3fecfb6
# 742bc40
# 1330415
# 5b87a5b
# 7a0b5f1
# d26fa5a
# 84c4b5c
# 39311b1
# 9d76c94
# 56d4f26
# beb832d
# 023fb1a
# 3134dc4
# e9fdfdc
# f5ce390
# 87b1e7f
# 7f2da64
# 59fac3d
# 1860ab2
# 108c712
# 3b27af7
# b057914
# 68a6dab
# 8da29b1
# e96ed8c
# d34e070
# 0a577c2
# 89dbd31
# 7ec87e8
# 72fcac4
# c590453
# 0393d33
# d4ea54e
# eaebcf4
# 9d8f28a
# 8f334ca
# b23b84b
# 51560a3
# 6ac1b41
# 2e20dde
# 646513c
# 1742e8a
# 2088737
# 74c289e
# 21cc381
# 596c414
# 4c2ddfc
# 95d4a38
# eab40c5
# 260d48d
# 3285b60
# fe6f1d8
# 127b031
# 21c2e0c
# 19ffb8a
# 2d16a39
# 9ba3377
# be63dfd
# e5304c6
# 3994e3c
# 87af839
# e45ff9f
# 50bb453
# c7e91c8
# e82b561
# c8dd12d
# 4439855
# 798e08a
# 90c9854
# 2e3a646
# e3366a9
# e6f27eb
# 330f3fe
# bbb5e1e
# 37680e2
# 1861674
# f0b12de
# 8581b76
# 50b8f0f
# 13d22f4
# 2af7228
# 3e7a3e8
# 6de80346
# 909e6d2
# 917342a
# b68a2ca
# 328c42a
# 5873d50
# d59f8b2
# 7458770
# c279266
# a204eb0
# 31b8384
# 4a07f43
# 6bf1c2a
# 3266e8c
# 2671c94
# ef67b09
# ed400a8
# 1d852c1
# dea89fc
# e4ab3df
# 66c4410
# ce95573
# e2a5747
# 7d88f20
# 4513e75
# 2c86e2c
# 60f0dd1
# f80960e
# 440c9e1
# 02f92a3
# 6db6f36
# 827f2be
# 6806ace
# d470239
# a6f014a
# 1803798
# 126b3e5
# ba4b266
# 76fa806
# 9f69afd
# b9ff3cc
# d4f113c
# 3306daa
# 2ca334b
# 50747ca
# 1b989ad
# 21af49c
# e3b42f7
# 09e3588
# 0b78d9a
# 2ce0a51
# be0d580
# 7855e7c
# 82377f0
# 875bdf0
# 91f9106
# c8e8a51
# 5534811
# 586de10
# 39cf5e6
# ef02884
# 86c2739
# e8d1ff6
# d601341
# 730e378
# 7700792
# 2f066a5
# 34fef65
# b8d5b88
# 8afbbb7
# b660833
# de2c98d
# c5e91af
# 058ce10
# 3c319db
# def9fbf
# ef9041f
# 7d08e96
# e999ff7
# 56de24a
# 090d704
# 94e260f
# c1a29c7
# 538b031
# 68248a2
# 5a3c5f2
# f1572ae
# 8d2eacf
# d2cfe22
# baf8a3b
# ffe89d0
# bb2ebc7
# 827d5ea
# 7492b02
# 5eb2de0
# f72c996
# 017f764
# 610666e
# fcc8b11
# bf87c93
# 5d0946e
# 755ba84
# 7f67bad
# f80566a
# 5104af5
# 4bf57a6
# 4ff539e
# d07d83e
# 03727b9
# 54cf859
# 4b1ac70
# 4c23414
# 7c70651
# c88ba4f
# 2e221fa
# 039344a
# 3fb7269
# b522106
# 7cd1609
# a043865
# 9cd60db
# d8319bc
# b59857a
# f818507
# d0ab2f0
# b279f99
# f967e2c
# b413b0d
# e1b374d
# 48c0c45
# 1321357
# 8b36880
# c2ddabd
# 6536def
# 5166d56
# 036d2b3
# 76a6068
# afec931
# b6ad082
# 7707b0b
# 3eb3573
# 634a879
# 5b2451b
# f345089
# 9ca71cd
# 8604791
# e6cc3e0
# 0053765
# 3a0754d
# 4fb53c7
# de27e60
# 20733bd
# 907d55e
# 8ff8849
# 305cd95
# 9166969
# b5dcf30
# e4f6ee8
# 09f42c1
# 2a46139
# b632889
# 7a6670e
# 99b4221
# 0d7fa0f
# 831cf9e
# 5fb92f9
# 4ba1b2b
# 9446a68
# fc55e29
# 48afe6e
# cfcd4cf
# ec64a64
# 2d7c514
# 45afcbc
# 744562d
# 72cf3ea
# d56fa5d
# eb6ede4
# 210d50c
# 66ed690
# 1870b0f
# b3d68ad
# b045591
# 5b9e92b
# b00700c
# bae38c1
# eb784ba
# f9dafb8
# 55c2d75
# 3bd4ebc
# 6a23f66
# 4d95c18
# 203628b
# da5cdba
# ed5fdf6
# c377b9c
# 6eb146e
# 19502ba
# 0df6e2d
# e9bac4c
# 6446b6a
# 5579529
# 1e9fbc4
# 3bbddff
# c6b6d50
# 3873909
# 434e962
# ed72846
# 4c165b0
# 593de8e
# 64d35b5
# 6be6593
# da16f1a
# 0e68e6e
# 46207d3
# 1131e19
# a5fce33
# 846ceed
# 2f29f71
# 97ce809
# 7ed446a
# 5120484
# 7491d6d
# 32ef2f9
# 98b9ed7
# 4870fa9
# 38f8571
# dc1f09d
# 789f03f
# d78d9e0
# 5577be2
# e9c6d1d
# 98e22d7
# 7f9c5b6
# 88c700c
# 71ab26d
# 782a4a8
# 1a3937e
# 6fb7c7a
# 6208e40
# 4e00cdf
# 66ad98c
# efce868
# 6574d80
# 340642d
# 4cc354c
# 177c1f5
# a22d1fd
# da58a64
# 0b135be
# ebb687e
# 6f7be9d
# 3519525
# 80d2042
# a1ef303
# 2c6e219
# 18c7ba8
# baa06c8
# 246031f
# fb3c9ff
# c11f219
# c00ac81
# 804309e
# 61a188b
# 7326a39
# a6d59fd
# d20bc8c
# 7b346ee
# a303f3b
# f34a8dc
# 0270b66
# 00ee0d1
# c3d3e5e
# 636dd19
# 6393b4f
# fdd43ba
# 9c32072
# a42822f
# 909a315
# cbfae3e
# a10db78
# 83ac308
# 9efc285
# 91c94b8
# a503809
# 2be70c4
# f082dd4
# 573785a
# afef5ee
# edf9205
# ad48588
# 97583ab
# e3c25c9
# d9df107
# 579230b
# 2e81ed7
# f05a116
# 7306005
# ac8a7b2
# 58c073d
# 0c38504
# 3114d4e
# e06fe05
# d773adb
# a82b8f8
# 1fe3ea7
# a09f995
# 117852d
# dde7ece
# dadc732
# 617b061
# 0e62a37
# d3064e5
# 43dd0dc
# 9ddd3db
# 472ef54
# b6889fc
# 2fdf5aa
# 9967ac8
# 21450bb
# 4567b33
# 425bd83
# b159277
# a7b147c
# 3fa5658
# 7486b9e
# 3436cec
# f5f0f31
# 78d0c4a
# 0b35625
# 52386ac
# df885f4
# 20b13d7
# 390155b
# 42a96a6
# 1a42d79
# 58d2053
# 04436e8
# c57dfd9
# 6d4b5cd
# 2ddd9fe
# 04adbf9
# a4bbdaf
# 6be2ee9
# 3dc3619
# df9e863
# cc71409
# 9ee6eef
# 00fea9d
# d3892cb
# 712c03f
# ce645cc
# 2636e96
# 2b285b1
# e1b7224
# 73a2943
# 497c1f4
# 82ff5d1
# 7ff75d7
# 269eb51
# a763f3e
# 455c730
# 6f04c3e
# 0737474
# 6541d69
# 2a73e3e
# a66b9fb
# beb40e7
# 96bb488
# fb84d9c
# feb43d6
# 623ba57
# ef98fd3
# a1fe354
# 988e784
# b3bc2b5
# f6393a2
# 3ae7cd3
# bd82d75
# c672fe3
# aca98c7
# 18669bb
# 915d6f1
# 87f65fc
# c54d3a8
# 45add3a
# b139232
# 4245197
# eba263a
# 76d1299
# 219bf9a
# 438b547
# b67bf47
# b8a0427
# 42b7276
# d4bd0b3
# 21605e8
# 30686a1
# 0ded6f7
# f40cca1
# b3d476e
# f0ad696
# c9240a2
# a5bad2b
# 19a21f5
# ba96c9a
# 81648e8
# ff921dd
# 3d4d064
# 1905a9e
# 39ce9a1
# 6d0cca3
# 9bd8d5c
# b8b6e22
# 2cbace2
# 6830591
# 15c12f1
# 071da06
# 0d5a7c1
# 7efbda8
# 676a8c3
# 51c98c2
# ac40942
# d085906
# c367c49
# f0a26f7
# d655c3c
# 9219569
# e21cf43
# 810dfa3
# 060ebed
# 7c20e47
# 555e468
# 34b6782
# 4d4edd6
# 6984da7
# 88537f8
# d6f6b71
# 09ac2f8
# f30183c
# df47b10
# 0e826cf
# 684ae52
# 3972fbb
# f9bad20
# f8d5875
# e6d7d0d
# 341fedc
# 533e5bb
# 60deb4c
# 250c578
# 1751328
# 3a68559
# 47ce734
# 03d2fab
# 287bc0e
# cf1e53b
# 0920520
# 769a1ba
# 9ab84d2
# fbcc1ab
# 4d3ce1e
# 45efe1c
# 399f280
# 49931ff
# 3c3b871
# 4f81905
# e260d84
# 7c42d54
# 10c5911
# 9f82e42
# d16eccf
# 1b539ae
# ad4076c
# 2223a55
# 36f716d
# cc6b08f
# a5537e5
# c298aa5
# d3d2350
# 8f1f532
# e38bbe5
# a4900c9
# d01b06c
# 11b1b60
# f31a72a
# 21cc813
# 5e87378
# 97d623a
# 26dd73d
# 67d7ea5
# cc53d3a
# cda314a
# 154b791
# 2a4571c
# eb60d3d
# b418a08
# 8dd6c42
# dc5fdf7
# f45eb1f
# 8071054
# 01fb77e
# f76eda6
# b400440
# 31c6506
# 278ec09
# 1a1471b
# d03df85
# 5bfbf61
# e02f414
# c629184
# e46d3bf
# b9d90ed
# 36d8798
# 79a29c3
# 26208c1
# c26e90f
# 2f5435a
# f037e5e
# 65e6fad
# 0e86e92
# a517057
# 3f1319f
# cf05684
# cf1726f
# 294ab9c
# 61b8b01
# 5dcca48
# ffcaeb0
# 76495c3
# 14793a7
# 91bbbb8
# fc02420
# 2e7caff
# 32209ce
# 1d1e1b8
# 91ad3fd
# 0308fc3
# 32627c6
# c6afdbb
# 96f544b
# d02d010
# c1595c2
# 9733c58
# 6033d14
# d05f261
# 0b954c5
# 107e722
# f0b3465
# 32b81ba
# b7d5986
# a8f437d
# 834ced1
# ec2f2d2
# e8184c8
# 0102842
# de2670a
# 743f6a6
# 05d13b6
# ad61877
# c7bcabb
# a6231ae
# c072140
# 46dc676
# 83b2373
# 3b27ede
# b722e14
# 3729364
# a18d17c
# 8bbc09c
# d5c80d1
# 51d399f
# 18a2e90
# 3bfa7d1
# 6992806
# 12aaf01
# b68d09d
# 37594a4
# cc79efb
# b3409a7
# d43bb18
# 24fb136
# c8d5695
# f981077
# ff78939
# 622f5b5
# 0d196a0
# f367b26
# 9be0992
# aaee316
# a79c0bb
# 7e4a6f8
# 7b764d5
# 0533449
# dcae778
# b660785
# 49780d3
# e2efec0
# 44e0eeb
# 588b93a
# 3c8c951
# 6cca072
# f4ce7b5
# 5c760dd
# 69f71c5
# 73f74ad
# 381176f
# 9054aac
# 8743063
# 68611cc
# 244b310
# 6c3e60b
# 0264e58
# ecfebf7
# 370a783
# 93f7fa5
# 255ebd2
# 816bbc0
# 74ff198
# a1b027b
# b9b5413
# 4959064
# dc9c694
# 104dbac
# 272ead5
# 4b75615
# 8302dd0
# 7a6bd26
# 5a53227
# 278366b
# 8348f00
# 11b686c
# 845ace0
# 6d28ba7
# 7285331
# d4e1396
# 255364a
# fb076ae
# cfe62b0
# fb5172c
# 233cbc5
# 0f9916e
# 3893152
# 2a29e2e
# e21a8f6
# fbe7e76
# da6d030
# c7ccab6
# 2f7356c
# 4b1d1f1
# 3b54252
# 6423083
# 4020136
# b12a2b0
# b172c52
# 3dfc590
# 1e8f480
# d7d514b
# e6cf8a9
# c118e62
# 6a56e1e
# b21d6c1
# e56a4f0
# 74cd1e5
# 21bb4a0
# 9753686
# 757b8d5
# ec427d1
# d7f23ef
# 3cf9de3
# 4bdebbf
# 51ec76c
# 8742126
# 3c3ccb7
# a3200e5
# eb1b2cf
# 36b2203
# e3aebab
# 15671e2
# 284dc10
# d7bdf92
# ceaf74b
# 98cfeed
# 0d52eb2
# 92fd840
# a71e2a4
# e75d06a
# 733e652
# 348ec67
# ea364f0
# 16c4d04
# bd64816
# 0e0e0b5
# 5f65d16
# 4538d3d
# 01ae040
# 26acc08
# 13cf383
# 27b0d6d
# a2f8a1e
# 120e9f5
# 31a4af2
# 30e2fc9
# 0a473a7
# 6a360c7
# 16727eb
# 97fe18d
# 983b064
# 49a9b44
# 76e8b58
# 71f799c
# 47fc86a
# ba818fe
# 38844d1
# 6d908e5
# dd73c91
# b1a4431
# 970afd6
# 7e00cc3
# f76efe5
# 30bacfb
# a16f538
# c3db036
# 8de3eb5
# 6a07726
# 583d981
# 580b955
# da153bf
# 0f12bac
# 82d2bae
# 590ce80
# 012b2e9
# 40b47ce
# 5481717d
# 2bc1662
# aa25e82
# 33ec665
# e9877e5
# c2659d3
# 9707f8d
# dbbb7c7
# d4a0b9e
# b28b68f
# d7746ea
# 43ed500
# 26e3a26
# 8d6fe81
# 794cbbc
# 4201963
# 90279e8
# 86d92c9
# d9e1669
# 5332735
# 1eb0c0d
# c2e02c9
# 9c1000e
# 5d21709
# d2a5bc0
# 91b44a1
# 9102bea
# dd7aa20
# 188ddd4
# 80b1e90
# 0db46cc
# 2d734bb
# d13d1dc
# ad93f56
# 7053ca8
# 917b65a
# 229bbd7
# f8b575f
# 38876a5
# 7ec3424
# f27f087
# 7dadc2a
# 1909dbe
# 986597f
# baf90f0
# f6464ec
# b848e5c
# a4f9188
# d4e5f1c
# 53335ba
# 70f2914
# 3b86bd1
# a226f3c
# 1feabd3
# 145419f
# d64c176
# d370dcd
# fbd4691
# 2dff587
# e44b043
# a758b7e
# ee555fe
# a74f9eb
# 791ce92
# e38ef22
# 83aa5b0
# 3fd6780
# c25bad3
# 87933eb
# 76fcbc8
# 7bbad39
# b1713b4
# 2b2bdac
# 1634815
# 65c7c96
# fc505bb
# 28f28f1
# cfff0e3
# 1d3a7b6
# 96eca83
# 40c5b89
# 07d703b
# 405e396
# 8c13108
# 512526d
# cb50fe9
# 3693e02
# d96ea7e
# 754043c
# deebf2d
# ef0f083
# d81a1df
# 7d375de
# 69463d9
# 1eaea0b
# 526cab3
# b4899f6
# adc837a
# 006e834
# aa6149b
# c168b68
# f62b589
# 5f33585
# f7f9886
# 160b650
# 6c8a0cb
# 1bc8da8
# a42fd5f
# 5908f8a
# c7286af
# 7974b57
# ac0ee45
# 615ca9a
# 103f123
# 90dc5f6
# a2711c1
# 7272826
# 87097c6
# 720ecda
# 696375e
# f680d9d
# c8fa333
# 1c93d7e
# f4000f2
# d3a28b2
# f41fcd8
# f184aeb
# 57dc658
# 4b9e8f7
# 9ab5af6
# fa7c12e
# 9d8efd6
# 9631f91
# 6e3d43f
# b4bbe34
# a07b560
# 6903e37
# fe62312
# f0d23ce
# 36debae
# e792f2b
# adec3ae
# 3cccd18
# 5baa816
# e78c3d1
# c23b7ab
# 50ffe74
# 4413f0f
# 4f87a2a
# 44a3c8c
# 094cbe6
# 9c478ac
# 445ff58
# 54bbe2f
# bb31671
# dd0259d
# f5583b8
# abc5ee0
# f773b18
# 3115f16
# 6d3185a
# b996bf7
# 89244b6
# 13b96de
# 60a1acd
# 1eb4b8a
# bef2551
# 9f2325d
# 2ab781b
# 6537e18
# fa959ca
# 5340227
# 4fb38cb
# ebac594
# 2253de7
# 778baa2
# 3e72e3a
# 473f7f5
# 8ffa1a5
# 9cb8e5f
# 77a17f9
# 79ba48e
# 7e65c5d
# f4bc01f
# 0387c81
# 7c4c349
# 1ea4c42
# 233fb22
# f604a9e
# 939f6a3
# f81ca44
# bb92ef0
# dc190c3
# 7a01d51
# 416ed79
# 3729fba
# 279f080
# cf766c0
# 9b80ac1
# dade0f9
# ed42d25
# 2e96379
# 5f3aad8
# 582967f
# c4f7de9
# 8f04892
# 30304de
# fcabfb5
# 46af818
# 1492aca
# dddb898
# 3181126
# 2c281e0
# 90f8b1a
# 78ad153
# c09c944
# b25bec3
# 5d16b13
# 1161903
# 87ccced
# da4756a
# b283304
# 389154b
# 556c577
# 6caf529
# 4ff18cd
# 31c3cf3
# 5147ff5
# f11ad9c
# 5d891d7
# 78b3cfa
# 0dd8d61
# 9fd985e
# b16a088
# ab2336b
# bc7e7de
# 61da52d
# 384a216
# 68c6b9e
# 356cec4
# aa09ac7
# 29c3b75
# 1687372
# af0580f
# 7f328e3
# 1d98f1d
# 01cb4ed
# ac33537
# 2c339bf
# d69cc30
# 098d6d5
# 01bc6a7
# d06e7b7
# 034b4d6
# af4ee07
# 8acd079
# 0fb1634
# a3b45ce
# d25a5b4
# aefdc2a
# 09e3ca2
# 79522bb
# e14f74a
# f3f90a3
# 3cf54d2
# 5d1db75
# aecfd52
# 01e82da
# ff0352d
# 3081ee1
# 380b8f9
# de33532
# 9c25f44
# ceb27fe
# 0dfd7e6
# aab15d0
# 523df0c
# 39e2ad8
# d607614
# e62bb3b
# 0fd871c
# b1408ff
# 3962779
# 47c5f8a
# 59cfef1
# 44492ac
# 977c576
# d6555de
# b30bff0
# 0263d1f
# 8404231
# 340af23
# dc3d8e6
# 8ea4ff3
# c44b200
# a9ececc
# 663b053
# b704ce8
# dd7c8df
# 136132c
# 7f94e85
# 4ae6314
# 26ca02d
# 9b6224b
# 1ceccd4
# 822aec7
# e577a60
# dd273c5
# e0da300
# b3ed241
# cc7e3e7
# bd345d9
# 9ca7fb7
# 788953e
# 1e8de82
# 138baec
# ca1ca92
# 5835bcd
# 6e24298
# 65b5040
# 8e3d975
# 3ced4f2
# 7d903ca
# 6e3ea68
# d620d8b
# 606a202
# 12968ff
# 154551f
# 051edd3
# d21aea4
# 0d171bc
# e8799d2
# d962ba0
# 2e8a54f
# e61d2aa
# 0905e8c
# 9c04d14
# ec9f2c4
# bbef280
# 5393962
# 1f1bc15
# e91dec7
# c2b8c06
# 43af48f
# 3490c09
# ae23a7f
# dee14c0
# 79c28fa
# 1d10d02
# 4812d09
# ba97018
# 87633a1
# 14c336d
# 656f9a8
# be4cd67
# 7c97e5c
# 6f06aa0
# dd0ddef
# b05f8dc
# 71b3181
# 8c1d40b
# db9fb4e
# b631eb6
# 292e891
# e837f7c
# fd5e4bf
# 39e7aea
# 337e3fd
# 811d7fa
# 26dac5a
# 6d7818c
# e200df3
# 62d4e33
# d6beaea
# 4dea9e4
# a0943be
# 966160f
# 89dfffa
# d30c941
# 3dc75f4
# 900592f
# 96287d3
# 3ef8840
# e67c3a6
# e1ceab4
# 8a1a916
# 31aad64
# f335e5a
# 327124c
# 4ece188
# f36be8e
# 0878ad4
# 43e358e
# f2e822a
# abc35fa
# 317793e
# 6eeb2b3
# fb1855a
# 6d30434
# f894722
# 7808ac2
# 504d72f
# 9f09783
# 2a0d7fdf
# c662c41
# a16f9d9
# 4a0d76d
# 486d969
# b74ed97
# 7212033
# 59dcb04
# 53e1621
# eab0f24
# d6a438e
# 2ad5ef6
# fec595b
# 7528388
# 85edad8
# be6ab60
# cb0f361
# 994d38a
# 3380ed1
# c3e129e
# 03e341c
# 4c9d06c
# 1f8c443
# bcf7af8
# 01e654f
# 019a81b
# 42a5d2f
# e8ac7d6
# f0f4dc4
# 3037c15
# 2e4976a
# f07d359
# 2f4dd12
# d137e7b
# 37ba2ff
# f75e841
# 73b92de
# da7547c
# c8874d7
# a7ee33b
# 34a8ad1
# 6fff3ab
# 1c538d8
# 7050f54
# c01ea62
# b0b3481
# 04ba9f0
# 7e41497
# 715a5dc
# df3dd4c
# 65cbdad
# 7fa2206
# 583ab8d
# 2283b09
# 117ad82
# 92990a7
# 4fa80e8
# 90e58a9
# a28f068
# 97448ad
# 3bd12a2
# dbbf24f
# 0e3aca4
# 9244450
# 6a638f0
# 3bf746c
# cffc80a
# 02a9807
# 379747d
# e025ce1
# 3c4b780
# 1b22672
# 0b7ac62
# c6a3136
# f5146d6
# 9e94c3d
# db089f4
# 6b6c8c7
# 65a7b0d
# c95eb0b
# a570695
# 2122690
# 5f22b72
# cd8734b
# a38f94b
# c627d32
# da7d710
# 4c13fdf
# 296f2c6
# 0a44156
# 378c6a3
# 466fdf5
# f2b574e
# 4924022
# 9be86f6
# 8de8a3b
# 18b61a1
# a701b9a
# dc48489
# cf5ed13
# a5de7d5
# e5b731f
# 089df61
# 14a77ce
# da294cc
# 81d127c
# 1ae1904
# 170b3d1
# 812995f
# 9443a8a
# 5a3083c
# 8a14184
# 2ce25c4
# 6f043a3
# 38c7118
# 9e2a047
# 259957e
# 544ae4a
# 1311ad1
# 0c4ed4f
# b56ef81
# 036bbe2
# 240450f
# e01e37a
# 42cf680
# f278606
# 8418371
# c306762
# a9c242c
# a93b56b
# e9b7a1f
# 0bfe55d
# c9d5302
# 3cd9130
# 314c516
# 8cc888a
# 4569cca
# 1e42e6b
# 9d3a3ad
# 081dc33
# 3fcf1be
# 336af06
# 363228b
# 9c2f4a9
# 37fb4b5
# 2109b5b
# a04a035
# ce8aff1
# 361239c
# b80bab2
# f6b2283
# cf9d715
# b0a49da
# 8fd1834
# 2f65d00
# cb6ba88
# c92a3d9
# 5c1e4e5
# d6d2b67
# 7695a8c
# 602e3fe
# 62bed05
# dbae4b0
# 3325ab5
# 9494bae
# 8dad16f
# df0fca3
# b2d25e0
# 5c8eb07
# 91dd804
# 4eb810e
# 0a76fb6
# afee802
# bd8f05c
# 75f5c92
# d0c52c4
# 08a57af
# a12bab7
# 63c5ec9
# 4e6ce15
# 3c384f8
# 24a6a26
# 1b48dba
# 0832bf9
# 62199a3
# b2e4c7c
# 7d10ae8
# efabab2
# 0694130
# b9f4e91
# 0aab32b
# 218b803
# 2d48981
# 3dd4417
# 8b52d99
# 05abcce
# 730e5ac
# 207eb42
# 3c76851
# b194614
# cbdb53d
# 70e2a2e
# 9185822
# 0443068
# f62c079
# f3d9ac6
# ddf7624
# 47cf7b0
# da00b52
# 82d1aa2
# 6722abd
# c0f3bda
# 0addaa7
# 55ba297
# c0fe460
# e740778
# 7d7e399
# c849836
# 921b723
# 4107cb5
# daa2078
# a033d9d
# 0327231
# e0a760f
# fe9c3b8
# 8065360
# 6c2b6d6
# a780db1
# de8ae4a
# c808a78
# 53545a1
# 2291c8c
# a0bbb9a
# 2246f3b
# 799abe1
# 379ad27
# 780e02b
# 15dc089
# 901b8a9
# 0fa07f9
# 8275bfe
# 9c2b5cf
# fa13ca0
# d539bb5
# 1757b97
# 73d5ab1
# 1ac1834
# 446457d
# 23381b8
# 91d0741
# e265ca5
# f048bce
# c6a0863
# e497d61
# c9d6f78
# 35d0d2f
# aa200f7
# 6de4eb7
# 9732372
# 95d2cf0
# 8de9de7
# 189717f
# dfd9f06
# a251f02
# 23d8435
# e14da1e
# cf02f34
# b4a6a0e
# d137ca4
# 70ba737
# c3603b9
# ec17cb3
# 2dcc0cc
# ac12f10
# b53f5d7
# 6ae7eb0
# 2f29b1e
# 41f2127
# 42928c1
# cbbcf48
# b6f2a44
# d639891
# d967c53
# 08d31ff
# ee76cb3
# 86af182
# 7ed9bad
# d2ada86
# 0831463
# ea2d3e8
# 1171b87
# 03bb3ee
# c066ec3
# b5dd815
# bd4ce14
# d66c2e6
# 1c2c0d9
# 4877e67
# 57efba9
# 003c98d
# 238197e
# 178ce1c
# 1a8c537
# 62b3877
# 0c84b28
# 43336b0
# cdd62a0
# 90439e5
# 36a8485
# dbe7842
# d84a587
# d27e072
# 3590bdc
# 6b108c0
# 9c55428
# 2154423
# b5e1071
# f8a9ce8
# 161a915
# d0f752f
# d4e2da4
# 0eac35b
# e593b63
# 6c65646
# 8d35623
# d792ae7
# fde0835
# 58a688f
# 605b115
# f3acb06
# a5f0c0d
# e44f040
# f62547e
# 584e732
# f46ebfe
# 55a5e54
# 382b573
# 6fbda16
# 6750484
# da1a591
# 9c8d2c7
# 3597812
# b871130
# d3cfb2a
# 9593ad6
# d097823
# c925531
# 8db62e2
# 0b5d49d
# 2082ade
# 7a57ceb
# 82545c8
# e1df5f5
# 9fb5d27
# c0e9456
# bcd864f
# fdcad35
# b03d685
# 8cd536c
# 2ada3c1
# 96b1276
# 2f4dff0
# 1a6bb87
# 8a06d5d
# 1e8bd16
# ae6753d
# a22972b
# a7faf40
# 5135119
# b5cf53f
# f32c25c
# a889c1a
# b578302
# 32f05fb
# 8541f30
# 8cb418e
# 9768643
# 1a47f53
# 95836d8
# fbe5656
# 911f0fe
# 2628b29
# 7ff6d07
# 6eec202
# 8c8e46f
# 7f88773
# 58b5609
# 924b6d7
# 2f8f04d
# 1155db1
# a521a82
# 8d69bf6
# 79eb4d7
# 36ce2d6
# 6fce0ba
# 46b75fa
# 4b1e08e
# 0982dbe
# 566b8c1
# d07f552
# 5f4e953
# 2fcdbb0
# 2ece00a
# 0dfcb4f
# f24be14
# 37ef255
# dcf5f32
# 0374533
# dda2b4b
# d3208d3
# 59e26bb
# 0646ef7
# b1d89de
# 323475f
# e4acfb1
# e6aa3f4
# 9157d85
# e9daa97
# 4bd84e3
# f72a905
# 87273d5
# 6ff09c8
# e3b6440
# 1f16f82
# bfaa68f
# be3dacd
# 800ee05
# ff3bab1
# 0fa6407
# e16786f
# e59742b
# 85a8ab2
# 63c7bc9
# 6378fb9
# 7cd3d82
# 3112f69
# 315778e
# 47dbe73
# a96ae79
# 95d6fcb
# fa15a15
# 85387dc
# 1422c5d
# 5b6969f
# 1d14365
# 3a8a968
# a96e597
# ee88057
# 9fafb86
# ea2e132
# 7a75e89
# b414e73
# 3ca8722
# e59d919
# 9e10fc9
# 72a0f81
# 4b7a359
# f5c5faf
# 5764c4f
# aeb7693
# eb86463
# 66648b5
# 176ac97
# 751a791
# de9ff4e
# b69a575
# ee08942
# f28a47e
# 6b7fe27
# 60f9913
# 074e866
# e8c9aea
# 09390c3
# d6e8487
# 6831e6c
# b523021
# 6120284
# dd7ae13
# 8ce4c00
# 29a7b90
# 72003ba
# 95ba92b
# 12ea5ce
# c95811b
# ec4c52a
# 95d9854
# 03a1d4d
# 8d4a233
# c52275e
# 0e91a5d
# 10dddc8
# cde5397
# 19ceb44
# 207b1dc
# e6f4e5f
# 8856126
# fa2d87f
# ac71549
# e95d9d1
# 602c21a
# b551cac
# 659f6c1
# 6d732db
# 8c5bbf3
# 82aff33
# d67bfff
# 8bf7df0
# 8f7a249
# e958565
# 583dffc
# 2466ed1
# b8789b6
# d3101af
# 37bdc7e
# c28099c
# 8dfb5ce
# 160fc10
# 42009b0
# 7790b9f
# 17238b2
# 1e04f22
# fdb92c5
# 94417fe
# 5faae53
# 7dcff7b
# e37e28a
# 6c051d6
# 0e09cbe
# 559bc9e
# 5979df5
# 274ead2
# 952b612
# a49a809
# 1b3341c
# eea1a9d
# 7d9003b
# 8979969
# 20b4a70
# 7f5f819
# d69852b
# 4b83ccb
# 50f4707
# 4703e5a
# edb9b62
# 9e22c25
# 03d2902
# aa08f84
# ebac9b0
# f5bd08d
# 7c190c9
# eb74d69
# c8d6f0d
# 5ced9eb
# 9be69ef
# 2974de5
# fd4c612
# 7d94ce1
# d3b7d9a
# 44a04a5
# 401c5e5
# fc94554
# a29ac35
# 9d83e04
# 19212b5
# fa66d39
# 2ab6902
# 920b7bf
# e1d6858
# 3dfcbc5
# a3022f3
# 7917dec
# 372619e
# 44c54b7
# c9eadc6
# 28d3fbd
# bd3dedb
# e971e37
# f780d5d
# a258bf5
# 0e547fb
# f85bf2e
# 8403108
# ed2d9a6
# fbf8712
# ca850ee
# e640d16
# 613791e
# 7d32eeb
# fa1bf17
# 0abf421
# a403e54
# eae3161
# 9220f38
# 8e43e2c
# 87521a1
# d929d19
# 6c1283d
# 231e2e5
# e6449cc
# 704342d
# ca7c2f1
# 975caf4
# 703a075
# e2774b9
# 4da6ec8
# 7ea0108
# 08997a7
# a311dce
# 4850e88
# 76ab3aa
# 2781120
# 6606533
# 508cb4e
# 2e8ab03
# 40555d1
# d92c1b3
# 2280928
# 7b0ff79
# e1da0ae
# 1560839
# 23c13a1
# 1d2078c
# 8968ba2
# 3dfb882
# d7695b8
# 034b1d6
# 6c1ed57
# 8dadbe0
# 0201406
# aedc127
# a94bf27
# b35f8a1
# 8bbdea5
# e7110ea
# e5f16ff
# 7385f76
# 5b82c88
# 40c365e
# 2384ac7
# c557eb2
# 6c905a3
# 72e8eb5
# 24588ac
# 6a6be72
# 69b9c63
# a717386
# 97e5598
# 23b0de6
# a792a2d
# b6a0d05
# 7a43f4b
# e703a2c
# ed492bd
# 7cf0c98
# f485a1c
# a0f3e04
# 26cf6d5
# 4eca0cc
# 4b6cf79
# 3119795
# aaaa530
# e9ee0ab
# 1ec0634
# fd0f875
# 98a3496
# e511f75
# ef53729
# 9bb7dd6
# ff3dc2b
# 2708b20
# 6f6ae29
# 7b37de8
# cc7a071
# 6656e6d
# a2fb21f
# b1e8273
# c69860b
# 79a13f9
# ebedf30
# 65f63d0
# 60c93e7
# 33ca1f2
# 75ba92f
# 99d6a90
# 7693648
# 9000d66
# 39a3013
# 055a88a
# 6fc2a75
# d67071f
# a86a277
# 8cfe8b6
# 01b9c2e
# af83fa8
# 076a21a
# 862e1b8
# 11c00fd
# d8ee180
# 5da5926
# 8ece39a
# 46287ca
# 9abf670
# 99cd303
# 96018f5
# 75a6dda
# 584fc0c
# 30a40fa
# 8be6ecd
# 4f18d81
# 5d2fe77
# a129a59
# fe68d98
# 876d133
# 0e9b000
# ca029c0
# 2c6b6be
# 32643d1
# 29b732c
# 83f759c
# 9ee47dd
# 6050551
# 1a57efb
# 94f8363
# 9f769ff
# 68dae65
# 12251db
# dbc0193
# 8b31f0f
# 7e3330a
# c562d68
# ad23e42
# d58dcdc
# dde5699
# a4a3eda
# 8cc5fa2
# 1668564
# f21635e
# 172367d
# 779d86e
# f2dde14
# 0b83d76
# 8f2301e
# 38d04c9
# dd64a3a
# a646a2f
# e356d83
# 5bcf05e
# 4bab561
# 41014f0
# 494f8bc
# 32e72c0
# 9dd3ddc
# a7755a3
# 4f354fa
# 544f808
# f1e04f4
# e96c654
# f062a6c
# c184896
# ad94f87
# ef26f22
# f0ee87a
# 683cf5c
# 1afbc98
# f967fc2
# 6e17e5c
# 20c62a2
# b552727
# 23bf64e
# 2ffbed6
# 830e823
# 69bf5a3
# b8a46f6
# a669eda
# 2806ec1
# 8b75ddb
# 1d6df43
# 1af415f
# a74b372
# ac17caf
# 12c2666
# efe7b9d
# 53483bc
# 4f57455
# f54e5bb
# 5c4de78
# 43b2afc
# e6dafb0
# e350740
# 479f777
# d838e25
# fa601ee
# 9283a8a
# 96ef54d
# a65f933
# f050339
# df5c1fc
# c7b489f
# ececa46
# 45f09fb
# 021d4b5
# afcb345
# 5d0d586
# 49c73ce
# 0b59d70
# 932ebf8
# d0f23d0
# 0cf244d
# b0a10f4
# 47cc547
# b98fe4c
# e65ba0b
# bc84c00
# 408e9c9
# a372c57
# dd2c7bb
# 76d27d8
# 5994649
# e1e1dd9
# fd77bfb
# fd76723
# 0cf17f8
# 1f89e22
# b609686
# e045f37
# d76a581
# 718a708
# 0509377
# c9aca98
# 11e69ba
# c6c75c6
# b52aa9c
# 2cf2742
# cbe53d7
# d82fba3
# 61d0d19
# e4fa9d0
# 4b251bc
# f6ce28d
# d65cde6
# e6a02c7
# 5e3f776
# ec21789
# a356bfe
# 329908e
# 3571238
# 6c43b05
# 6db984f
# ffadea4
# 35396f7
# 8544714
# 590bc96
# 90d3a37
# db5537d
# b9d4365
# 205f072
# 41ad5a2
# 5914a95
# 8cbd638
# 6375e63
# a1bac12
# f9b16a4
# c2ee904
# 8ddd890
# a49d74d
# ac851ff
# 2bd94c6
# 67d1d36
# 26c81be
# 9288246
# 9a6556d
# 3f3ad38
# 907de17
# 8507828
# dfe5abd
# 63154e9
# 9f6c9a7
# 96c53d5
# 25df981
# 47574cb
# e63fc29
# b684370
# 581c4cf
# 912d9be
# c7b14ac
# 3c4b2c5
# d7f9542
# 9aeabf6
# c6a511b
# 9212e94
# 9fdb5af
# 8e34009
# a68a3b0
# 2618bdb
# 7aa3414
# 6f35d5b
# 3d0ae26
# b9d127d
# 8d6f28a
# e7d972f
# ede34d9
# 2711b5c
# e6275ff
# 430f487
# f47d83e
# 21d4609
# 2731fdc
# 68ea6db
# 452b1ea
# 7e0bd90
# 23ed9b9
# e532be0
# b8a417c
# 2b16916
# f69f443
# 516187e
# 0321078
# 61a2561
# 3a61299
# cc84446
# ff06a97
# 2cf58b4
# b5e1c85
# f8b5acc
# 32c54cf
# 546fef4
# f3ca8dc
# 5edec31
# 35b03a0
# f3843a7
# f6ded10
# 870a6d2
# 4c12654
# 858c6d0
# 77665e0
# 0415efa
# 634d68d
# 3fddf5f
# d653891
# f2b4579
# 5521b39
# 7512d76
# ec74cfa
# 24af0f4
# be430a4
# a772b98
# 0e29ee4
# 3667e4b
# 5e7000e
# 95d8400
# 467e76d
# 2210ab2
# a2bdfc3
# 28855b4
# efab3a0
# 24c3548
# 217fd26
# 86d5e41
# c94083b
# f88f7d1
# 9f0be75
# 6eeeb5b
# 60ac766
# 0b6173d
# d10251a
# 85121fd
# 6da2195
# ff69ef1
# 66b1718
# e71a807
# 2efb90d
# 1fbd106
# 652fb76
# 0b1fb81
# a823b1c
# edf2190
# 1f6e814
# 903b8a8
# f86918a
# 12f3fa8
# ef9cb31
# c64e312
# db4a395
# 10cb700
# 996bdd8
# b92cc9d
# 774b7a7
# 1795075
# 921a279
# 2a1acbb
# 4f88cf3
# e42bae8
# 7c45570
# 7c8dd3c
# 716fdac
# a4dff96
# 93cef03
# b852a8e
# 0f5e3e7
# d50d68f
# 654e874
# d2d4c5f
# 84f1ef1
# 02c96d8
